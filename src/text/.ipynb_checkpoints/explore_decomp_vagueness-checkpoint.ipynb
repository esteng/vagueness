# %%
import csv

# %%
# Out:
# 2226
# 56

# %%
# Out:
# 44

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/core/arrays/categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     383             try:
# --> 384                 codes, categories = factorize(values, sort=True)
#     385             except TypeError:
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     195                     kwargs[new_arg_name] = new_arg_value
# --> 196             return func(*args, **kwargs)
#     197
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     670         labels, uniques = _factorize_array(
# --> 671             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     672         )
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     506     uniques, labels = table.factorize(
# --> 507         values, na_sentinel=na_sentinel, na_value=na_value
#     508     )
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-de5ab52a62d2> in <module>
#      19
#      20
# ---> 21 sns.lineplot(x=to_plot_xs, y = to_plot_ys)
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     764         # Loop over the semantic subsets and draw a line for each
#     765
# --> 766         for semantics, data in self.subset_data():
#     767
#     768             hue, size, style = semantics
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/seaborn/relational.py in subset_data(self)
#     330
#     331             if self.sort:
# --> 332                 subset_data = sort_df(subset_data, ["units", "x", "y"])
#     333
#     334             if self.units is None:
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/seaborn/utils.py in sort_df(df, *args, **kwargs)
#      43     """Wrapper to handle different pandas sorting API pre/post 0.17."""
#      44     try:
# ---> 45         return df.sort_values(*args, **kwargs)
#      46     except AttributeError:
#      47         return df.sort(*args, **kwargs)
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4993
#    4994             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
# -> 4995             indexer = lexsort_indexer(keys, orders=ascending, na_position=na_position)
#    4996             indexer = ensure_platform_int(indexer)
#    4997         else:
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/core/sorting.py in lexsort_indexer(keys, orders, na_position)
#     207         # create the Categorical
#     208         else:
# --> 209             c = Categorical(key, ordered=True)
#     210
#     211         if na_position not in ["last", "first"]:
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/core/arrays/categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     384                 codes, categories = factorize(values, sort=True)
#     385             except TypeError:
# --> 386                 codes, categories = factorize(values, sort=False)
#     387                 if dtype._ordered:
#     388                     # raise, as we don't have a sortable data structure and so
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     194                 else:
#     195                     kwargs[new_arg_name] = new_arg_value
# --> 196             return func(*args, **kwargs)
#     197
#     198         return wrapper
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     669
#     670         labels, uniques = _factorize_array(
# --> 671             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     672         )
#     673
#
# ~/miniconda3/envs/miso/lib/python3.7/site-packages/pandas-0.25.0rc0-py3.7-macosx-10.7-x86_64.egg/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     505     table = hash_klass(size_hint or len(values))
#     506     uniques, labels = table.factorize(
# --> 507         values, na_sentinel=na_sentinel, na_value=na_value
#     508     )
#     509
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
import pandas as pd

# read in 
dataframe = pd.read_csv("/Users/Elias/Downloads/protoroles_eng_udewt/protoroles_eng_ud1.2_11082016.tsv",
                       sep="\t")

# subset train 
dev_df = dataframe[dataframe["Split"] == "dev"]
print(f"subsetted dev")
# subset applicable 
dev_df = dev_df[dev_df["Applicable"] == "yes"]
print(f"subsetted applicable")
# group by sentence id and plot 
sns.lineplot(data = dev_df, x = "Sentence.ID", y = "Response" )
# Out:
# subsetted dev
# subsetted applicable

# %%
from decomp import UDSCorpus

top_offenders = dev_df.groupby(["Sentence.ID", "Pred.Token", "Arg.Phrase", "Property"])["Response"].std()
top_offenders = top_offenders[top_offenders > 0.0]

top_offenders = top_offenders.sort_values().tail(100)
corpus = UDSCorpus(split="dev")

# %%
import re

def get_sent(old_name, split="dev"):
    line_num = old_name.split(" ")[1]
    sent_id = f"ewt-{split}-{line_num}"
    return corpus[sent_id].sentence

for id, val in top_offenders.items():
    sent = get_sent(id[0])
    predicate = re.split("\s+", sent)[int(id[1])]
    prop = id[3]
    print( f"sentence: {sent}, property: {prop}, predicate: {predicate}, argument: {id[2]}", val)
# Out:
# sentence: lol , last news message came out kinda weird , i was trying to browse the japanese website while i changed the text i was supposed to put up but i ran out of time so there are no real pictures yet ... but i 'll add the links soon sry ., property: was_used, predicate: ran, argument: i 2.8284271247461903
# sentence: Capt. Spastic 's Demented World is located at : < >, property: sentient, predicate: located, argument: capt. spastic &#39;s demented world 2.8284271247461903
# sentence: Today 's incident proves that Sharon has lost his patience and his hope in peace ., property: awareness, predicate: lost, argument: his patience and his hope in peace 2.8284271247461903
# sentence: lol , last news message came out kinda weird , i was trying to browse the japanese website while i changed the text i was supposed to put up but i ran out of time so there are no real pictures yet ... but i 'll add the links soon sry ., property: awareness, predicate: browse, argument: the japanese website 2.8284271247461903
# sentence: He deserved respect, property: existed_before, predicate: deserved, argument: respect 2.8284271247461903
# sentence: lol , last news message came out kinda weird , i was trying to browse the japanese website while i changed the text i was supposed to put up but i ran out of time so there are no real pictures yet ... but i 'll add the links soon sry ., property: change_of_location, predicate: came, argument: last news message 2.8284271247461903
# sentence: The wedding had to be postponed as family members fled the outbreak of the war , she said ., property: existed_before, predicate: had, argument: the wedding 2.8284271247461903
# sentence: Nina Chahine , 19 , who with her family was among the named plaintiffs in the lawsuit , said her wedding in the southern city of Tyre was set for July 13 ., property: existed_before, predicate: set, argument: her wedding in the southern city of tyre 2.8284271247461903
# sentence: All you have to do is become a member and watch your earnings grow !, property: existed_after, predicate: is, argument: all you have to do 2.8284271247461903
# sentence: The US lost yet another helicopter to hostile fire near Habbaniyah in the Sunni heartland , but this time the crew was safe ., property: existed_after, predicate: lost, argument: yet another helicopter 2.8284271247461903
# sentence: Based on specific intelligence inputs , Army arrested Ghulam Mohiuddin Lone , a LeT man , from Doda district ., property: change_of_location, predicate: arrested, argument: ghulam mohiuddin lone , a let man , from doda district 2.8284271247461903
# sentence: The First time I walked in there with my teacup chihuahua puppy I knew I 'd be here a lot ., property: sentient, predicate: walked, argument: i 2.8284271247461903
# sentence: The US Marines took most of Fallujah Wednesday , but still face pockets of resistance ., property: change_of_possession, predicate: took, argument: the us marines 2.8284271247461903
# sentence: The US Marines took most of Fallujah Wednesday , but still face pockets of resistance ., property: change_of_state, predicate: took, argument: the us marines 2.8284271247461903
# sentence: The US Marines took most of Fallujah Wednesday , but still face pockets of resistance ., property: partitive, predicate: took, argument: the us marines 2.8284271247461903
# sentence: The US lost yet another helicopter to hostile fire near Habbaniyah in the Sunni heartland , but this time the crew was safe ., property: change_of_state_continuous, predicate: lost, argument: yet another helicopter 2.8284271247461903
# sentence: The US lost yet another helicopter to hostile fire near Habbaniyah in the Sunni heartland , but this time the crew was safe ., property: change_of_possession, predicate: lost, argument: yet another helicopter 2.8284271247461903
# sentence: The US lost yet another helicopter to hostile fire near Habbaniyah in the Sunni heartland , but this time the crew was safe ., property: instigation, predicate: lost, argument: the us 2.8284271247461903
# sentence: We have Hobby Lobby , Just for Fun Fabrics , Walmart , and Interior Mall just inside Barling ., property: awareness, predicate: have, argument: we 2.8284271247461903
# sentence: The S100 has a slightly larger screen and the new digic 5 processor ., property: partitive, predicate: has, argument: the s100 2.8284271247461903
# sentence: The S100 has a slightly larger screen and the new digic 5 processor ., property: existed_before, predicate: has, argument: a slightly larger screen and the new digic 5 processor 2.8284271247461903
# sentence: This message was cancelled from within Mozilla ., property: existed_after, predicate: cancelled, argument: this message 2.8284271247461903
# sentence: This message was cancelled from within Mozilla ., property: existed_before, predicate: cancelled, argument: this message 2.8284271247461903
# sentence: The S100 has a slightly larger screen and the new digic 5 processor ., property: change_of_state, predicate: has, argument: a slightly larger screen and the new digic 5 processor 2.8284271247461903
# sentence: The intrepid Ed Wong of the NYT has more on the Sunni boycott of the elections ., property: change_of_state, predicate: has, argument: more on the sunni boycott of the elections 2.8284271247461903
# sentence: The intrepid Ed Wong of the NYT has more on the Sunni boycott of the elections ., property: instigation, predicate: has, argument: more on the sunni boycott of the elections 2.8284271247461903
# sentence: The S100 has a slightly larger screen and the new digic 5 processor ., property: existed_before, predicate: has, argument: the s100 2.8284271247461903
# sentence: I have lots of containers in there ., property: instigation, predicate: have, argument: lots of containers 2.8284271247461903
# sentence: " They can freely write anything they like about our prophet , but if one raises doubts about the Holocaust he is either fined or sent to prison , " he added ., property: was_for_benefit, predicate: write, argument: they 2.8284271247461903
# sentence: I used Birdies for our Annual Walk Against Drugs and Alcohol event ., property: was_used, predicate: used, argument: i 2.8284271247461903
# sentence: But if -- there 's a painting on the wall in the Oval Office that shows a horseman charging up a steep cliff , and there are at least two other horsemen following ., property: existed_after, predicate: 's, argument: a painting on the wall in the oval office that shows a horseman charging up a steep cliff 2.8284271247461903
# sentence: After several years of use , we arrive at the present day when the village people have suddenly discovered the fertilizer is actually the bottling plant 's waste sludge and is laden with cadmium , a highly toxic , cancer - causing heavy metal ., property: change_of_state, predicate: arrive, argument: we 2.8284271247461903
# sentence: I revised the language based on our discussions and added the language concerning interest which we had both previously approved ., property: existed_before, predicate: revised, argument: the language 2.8284271247461903
# sentence: Coca - Cola calmed the concerns of the people and attempted to win back their favor by giving them vast amounts of free fertilizer , saying it would grow bountiful crops beyond their wildest dreams ., property: existed_before, predicate: grow, argument: bountiful crops beyond their wildest dreams 2.8284271247461903
# sentence: I revised the language based on our discussions and added the language concerning interest which we had both previously approved ., property: partitive, predicate: revised, argument: the language 2.8284271247461903
# sentence: the waitress took my name and then called me that all night ., property: change_of_possession, predicate: took, argument: my name 2.8284271247461903
# sentence: But if -- there 's a painting on the wall in the Oval Office that shows a horseman charging up a steep cliff , and there are at least two other horsemen following ., property: existed_before, predicate: 's, argument: a painting on the wall in the oval office that shows a horseman charging up a steep cliff 2.8284271247461903
# sentence: the waitress took my name and then called me that all night ., property: change_of_location, predicate: took, argument: my name 2.8284271247461903
# sentence: I have no inside information , but I have been following links today that strongly indicate that Google is damn serious about securing permanent control of the leading edge browser technology in Firefox ., property: awareness, predicate: securing, argument: permanent control of the leading edge browser technology in firefox 2.8284271247461903
# sentence: In an apparently unrelated incidents , some eleven Iraqis were killed by snipers on Tuesday , including a group of police trainees in a bus near Hilla and two police in Kirkuk ., property: awareness, predicate: killed, argument: some eleven iraqis 2.8284271247461903
# sentence: Barb does an AMAZING JOB , she is always learning new things on how to use her hands and body , to give every person an AWESOME MASSAGE , CALL TODAY AND SCHEDULE YOU MUST SEE HER , YOU WILL FALL IN LOVE SHE IS THE BEST OF THE BEST !, property: instigation, predicate: FALL, argument: you 2.8284271247461903
# sentence: they have their own website which you can easily find using any search engine ., property: instigation, predicate: have, argument: their own website which you can easily find using any search engine 2.8284271247461903
# sentence: Barb does an AMAZING JOB , she is always learning new things on how to use her hands and body , to give every person an AWESOME MASSAGE , CALL TODAY AND SCHEDULE YOU MUST SEE HER , YOU WILL FALL IN LOVE SHE IS THE BEST OF THE BEST !, property: awareness, predicate: FALL, argument: you 2.8284271247461903
# sentence: they have their own website which you can easily find using any search engine ., property: partitive, predicate: have, argument: their own website which you can easily find using any search engine 2.8284271247461903
# sentence: I have a Norwegian Forest Cat that is named Achilles bc as a kitten he always attacked your feet when you walked by !, property: was_used, predicate: attacked, argument: your feet 2.8284271247461903
# sentence: It was ok , nice management , they let us check in early , but the place was old ., property: sentient, predicate: let, argument: they 2.8284271247461903
# sentence: Xinhua alleged that " Many of the Iraqis , who suffer the American occupation of Iraq , relate their case with that of the Palestinian people , under the Israeli occupation . ", property: was_used, predicate: suffer, argument: the american occupation of iraq 2.8284271247461903
# sentence: But if -- there 's a painting on the wall in the Oval Office that shows a horseman charging up a steep cliff , and there are at least two other horsemen following ., property: partitive, predicate: shows, argument: that 2.8284271247461903
# sentence: NiMo released an additional RFP for peaking supplies for this winter , I believe Phil should have or be getting that RFP ., property: existed_before, predicate: released, argument: an additional rfp for peaking supplies for this winter 2.8284271247461903
# sentence: NiMo released an additional RFP for peaking supplies for this winter , I believe Phil should have or be getting that RFP ., property: was_used, predicate: released, argument: an additional rfp for peaking supplies for this winter 2.8284271247461903
# sentence: I have lots of containers in there ., property: change_of_possession, predicate: have, argument: lots of containers 2.8284271247461903
# sentence: NiMo released an additional RFP for peaking supplies for this winter , I believe Phil should have or be getting that RFP ., property: was_for_benefit, predicate: peaking, argument: supplies 2.8284271247461903
# sentence: I wish I could have a slice for every single meal ., property: was_for_benefit, predicate: wish, argument: i 2.8284271247461903
# sentence: The information contained herein is based on sources that we believe to be reliable , but we do not represent that it is accurate or complete ., property: instigation, predicate: believe, argument: that 2.8284271247461903
# sentence: But if -- there 's a painting on the wall in the Oval Office that shows a horseman charging up a steep cliff , and there are at least two other horsemen following ., property: existed_before, predicate: shows, argument: that 2.8284271247461903
# sentence: okay .... I have a dog and my mother is really really terrified of hamsters ., property: awareness, predicate: have, argument: a dog 2.8284271247461903
# sentence: These agreements were forwarded to the counterparty , CCNG , Inc. ., property: sentient, predicate: forwarded, argument: these agreements 2.8284271247461903
# sentence: We go to Japaneiro 's all the time and we have NEVER been disappointed !, property: change_of_location, predicate: go, argument: we 2.8284271247461903
# sentence: The current complaints allege that HANO has not provided qualified former St. Thomas residents a preference with respect to available public housing units at River Garden per the 2003 agreement ., property: instigation, predicate: provided, argument: hano 2.8284271247461903
# sentence: The current complaints allege that HANO has not provided qualified former St. Thomas residents a preference with respect to available public housing units at River Garden per the 2003 agreement ., property: existed_during, predicate: provided, argument: a preference with respect to available public housing units at river garden 2.8284271247461903
# sentence: I wish I could have a slice for every single meal ., property: was_used, predicate: wish, argument: i 2.8284271247461903
# sentence: the waitress took my name and then called me that all night ., property: was_for_benefit, predicate: took, argument: my name 2.8284271247461903
# sentence: I have no inside information , but I have been following links today that strongly indicate that Google is damn serious about securing permanent control of the leading edge browser technology in Firefox ., property: existed_before, predicate: indicate, argument: that 2.8284271247461903
# sentence: I want to use this opportunity to welcome Brian Ryner to Google !, property: partitive, predicate: want, argument: i 2.8284271247461903
# sentence: Barb does an AMAZING JOB , she is always learning new things on how to use her hands and body , to give every person an AWESOME MASSAGE , CALL TODAY AND SCHEDULE YOU MUST SEE HER , YOU WILL FALL IN LOVE SHE IS THE BEST OF THE BEST !, property: existed_before, predicate: learning, argument: new things on how to use her hands and body , to give every person an awesome massage 2.8284271247461903
# sentence: I have no inside information , but I have been following links today that strongly indicate that Google is damn serious about securing permanent control of the leading edge browser technology in Firefox ., property: sentient, predicate: securing, argument: permanent control of the leading edge browser technology in firefox 2.8284271247461903
# sentence: I anticipate completing the review of the Master Agreement form and submitting comments to you by Monday ., property: change_of_location, predicate: anticipate, argument: i 2.8284271247461903
